# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_448\2085782635.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = 1000, n_features = 2, n_classes = 2, n_clusters_per_class = 1, n_redundant = 0)

# %%
pd.DataFrame(X)
# Out:
#             0         1
# 0    0.874085  1.385235
# 1    1.380449  0.239037
# 2   -0.949922  0.721576
# 3   -1.928853 -0.738841
# 4    1.995243 -0.901601
# ..        ...       ...
# 995  0.366573  2.042312
# 996 -0.833506  2.221504
# 997  1.296564  0.506517
# 998  0.811272  1.768395
# 999  0.411722  3.057143
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(x=pd.DataFrame(X)[0], y=pd.DataFrame(X)[1], hue = y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='linear')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 42)

# %%
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       134
#            1       1.00      0.94      0.97       116
#
#     accuracy                           0.97       250
#    macro avg       0.98      0.97      0.97       250
# weighted avg       0.97      0.97      0.97       250
#
# [[134   0]
#  [  7 109]]

# %%
X, y = make_classification(n_samples = 1000, n_features = 2, n_classes = 2, n_clusters_per_class = 2, n_redundant = 0)

# %%
pd.DataFrame(X)
sns.scatterplot(x=pd.DataFrame(X)[0], y=pd.DataFrame(X)[1], hue = y)
rbf = SVC(kernel='rbf')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 42)
rbf.fit(X_train, y_train)
y_pred = rbf.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       127
#            1       0.85      0.93      0.89       123
#
#     accuracy                           0.88       250
#    macro avg       0.89      0.88      0.88       250
# weighted avg       0.89      0.88      0.88       250
#
# [[107  20]
#  [  9 114]]
